# %% [markdown]
# ## Predictions

# %%
from tensorflow.keras.models import load_model

# %%
from tensorflow.keras.preprocessing import image

# %%
model = load_model("fire.h5")

# %%
img = image.load_img(r"C:\Users\Isha\Pictures\Saved Pictures\egnofire.jpg",target_size=(256,256))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1FBA5F2EB20>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
x = image.img_to_array(img)

# %%
x
# Out:
# array([[[ 12.,  14.,   0.],
#         [ 21.,  24.,   7.],
#         [ 43.,  46.,  27.],
#         ...,
#         [ 21.,  19.,   7.],
#         [ 13.,  15.,   2.],
#         [ 52.,  60.,  11.]],
#
#        [[ 13.,  15.,   2.],
#         [ 12.,  14.,   0.],
#         [ 18.,  21.,   4.],
#         ...,
#         [ 17.,  15.,   2.],
#         [ 10.,  11.,   3.],
#         [ 58.,  65.,  23.]],
#
#        [[ 14.,  15.,   7.],
#         [ 11.,  13.,   2.],
#         [ 10.,  12.,   0.],
#         ...,
#         [ 19.,  18.,   0.],
#         [ 17.,  18.,  13.],
#         [ 62.,  66.,  39.]],
#
#        ...,
#
#        [[ 14.,  15.,   7.],
#         [ 51.,  56.,  26.],
#         [ 48.,  57.,   2.],
#         ...,
#         [ 50.,  65.,  26.],
#         [ 58.,  75.,  30.],
#         [ 54.,  73.,  27.]],
#
#        [[ 17.,  19.,   8.],
#         [ 49.,  54.,  24.],
#         [103., 112.,  57.],
#         ...,
#         [ 65.,  80.,  41.],
#         [ 61.,  78.,  33.],
#         [ 64.,  83.,  37.]],
#
#        [[ 18.,  18.,   8.],
#         [ 36.,  39.,   8.],
#         [ 77.,  85.,  28.],
#         ...,
#         [ 79.,  94.,  55.],
#         [ 50.,  67.,  22.],
#         [ 52.,  71.,  25.]]], dtype=float32)

# %%
x.shape
# Out:
# (256, 256, 3)

# %%
import numpy as np

# %%
# convolution expects 4D
x = np.expand_dims(x,axis=0)

# %%
x.shape
# Out:
# (1, 256, 256, 3)

# %%
pred_prob = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 111ms/step

# %%
pred_prob
# Out:
# array([[0.]], dtype=float32)

# %%
if(pred_prob==0):
    print("There is no fire")
else:
    print("There is a fire")
# Out:
# There is no fire
